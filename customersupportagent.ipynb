# %%
pip install crewai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install 'crewai[tools]'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.0/765.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 8.8 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 16.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pymupdf
#     Found existing installation: PyMuPDF 1.26.5
#     Uninstalling PyMuPDF-1.26.5:
#       Successfully uninstalled PyMuPDF-1.26.5
#   Attempting uninstall: beautifulsoup4━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pymupdf]
#     Found existing installation: beautifulsoup4 4.12.3━━━━━━━━  2/11 [pymupdf]
#     Uninstalling beautifulsoup4-4.12.3:━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pymupdf]
#       Successfully uninstalled beautifulsoup4-4.12.3━━━━━━━━━━  2/11 [pymupdf]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [crewai-tools] [crewai-tools]-urllib3-client]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Agent,Task,crew

# %%
import os

openai_api_key="Your Open AI API KEY"
os.environ["OPEN_API_KEY"]=openai_api_key
os.environ["OPEN_AI_MODEL_NAME"]='gpt-3.5-turbo'

# %%
#Creating Agent (with role, focus, cooperation)
customer_support_agent = Agent(
    role="Senior Customer Support Representative",
    goal="Be the most friendly and helpful "
        "customer support representative in your team",
    backstory=(
		"You work at crewAI (https://crewai.com) and "
        " are now working on providing customer"
		"support to {customer}, a super important customer "
        " for your company."
		"You need to make sure that you provide the best support!"
		"Make sure to provide full complete answers, "
        " and make no assumptions."
	),
    allow_delegration=False, 
    verbose=True
)
# Out:
# Error instantiating LLM from environment/fallback: ImportError: Error importing native provider: OPENAI_API_KEY is required
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/crewai/llm.py:392, in LLM.__new__(cls, model, is_litellm, **kwargs)
#     389     kwargs_copy = {k: v for k, v in kwargs.items() if k != "provider"}
#     390     return cast(
#     391         Self,
# --> 392         native_class(model=model_string, provider=provider, **kwargs_copy),
#     393     )
#     394 except NotImplementedError:
#
# ...
